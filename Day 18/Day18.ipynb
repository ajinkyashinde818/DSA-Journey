# %% [markdown]
# # 🧩 Day 18 — Find the Pair with the Given Difference
#
# ## Given an array and a number k, find whether there are two different elements whose absolute difference is exactly k.
#
# Example 1
#
# Array = [5, 20, 3, 2, 5, 80]
#
# k = 78
#
# Answer:
#
# True
#
# Because:
#
# 80 - 2 = 78
#
# Example 2
#
# Array = [1, 5, 3, 4, 2]
#
# k = 2
#
# Answer:
#
# True
#
# Because:
#
# 3 - 1 = 2
#
# 5 - 3 = 2
#
# 4 - 2 = 2
#
# Example 3
#
# Array = [1, 3, 7, 10]
#
# k = 5
#
# Answer:
#
# False

# %%
def diff(arr):

    for i in range(len(arr)):
        for j in range(len(arr)):
            diff=arr[i]-arr[j]

            if diff==k:
                return True

    return False    

    Array = [1, 5, 3, 4, 2]
    k = 2
    print("The Pair is:",diff(arr))
